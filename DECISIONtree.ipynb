# %% [markdown]
# # Decision Tree
#  a decisicon tree is a supervised ml model that is used for classicfication
# and regression task thats why it is consider as CART
#
# it works like an flow chart or an tree structure where each internal node re4present
# an feature and each branch represent an decision or condition and each leaf
# or class label in the classification or in value in the regression
# a decision tree splits the data into subsets based on tjhe value od input features and this process is repeated regressively forming an tree like structure

# %% [markdown]
# # HOW IT WORKS
# it stART with thwe entire data it chooswe the best feature to split the data baseed on an
# matrix -----gini index ,antropy ,mse(mean squ error) thren it will split the data set into smaller
# subsets
# then it will repeat the process for each child node until a stoping condition is met.

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\DELL\\Documents\\covid_toy.csv")

# %%
df = df.dropna()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['gender'] = lb.fit_transform(df['gender'])
df['cough'] = lb.fit_transform(df['cough'])
df['city'] = lb.fit_transform(df['city'])
df['has_covid'] = lb.fit_transform(df['has_covid'])
df.head(2)
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      0     2          0
# 1   27       1  100.0      0     1          1

# %%
x = df.drop(columns = ['has_covid'])
y = df['has_covid' ]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train, y_test = train_test_split(x,y, test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.4444444444444444
